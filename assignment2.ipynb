# %% [markdown]
# Student Result Management System
# Create a user-defined function called student_result() that:
# 1.Takes the names and marks of 5 students as input.
# 2.Stores student data in a dictionary.
# 3.Uses conditional statements to assign grades:
# A: 80 and above
# B: 60–79
# C: 40–59
# F: Below 40
# 4.Displays each student's name, marks, and grade.
# 5.Calculates and displays:
# Highest marks
# Lowest marks
# Average marks

# %%
def student_result():
    students = {}
    marks_list = []

    for i in range(5):
        name = input(f"Enter name of student {i+1}: ")
        marks = float(input(f"Enter marks of {name}: "))

        # Store in dictionary
        students[name] = marks
        marks_list.append(marks)

    print(" Student Results")

    for name, marks in students.items():

        if marks >= 80:
            grade = "A"
        elif marks >= 60:
            grade = "B"
        elif marks >= 40:
            grade = "C"
        else:
            grade = "F"

        print(f"Name: {name}, Marks: {marks}, Grade: {grade}")

    highest = max(marks_list)
    lowest = min(marks_list)
    average = sum(marks_list) / len(marks_list)

    print("Summary")
    print("Highest Marks:", highest)
    print("Lowest Marks:", lowest)
    print("Average Marks:", average)

student_result()
# Out:
# Enter name of student 1: PRANJALI
# Enter marks of PRANJALI : 100
# Enter name of student 2: DIPSAN
# Enter marks of DIPSAN: 75
# Enter name of student 3: MILAN
# Enter marks of MILAN: 50
# Enter name of student 4: RAM
# Enter marks of RAM: 39
# Enter name of student 5: SHYAM
# Enter marks of SHYAM: 80
#  Student Results
# Name: PRANJALI , Marks: 100.0, Grade: A
# Name: DIPSAN, Marks: 75.0, Grade: B
# Name: MILAN, Marks: 50.0, Grade: C
# Name: RAM, Marks: 39.0, Grade: F
# Name: SHYAM, Marks: 80.0, Grade: A
# Summary
# Highest Marks: 100.0
# Lowest Marks: 39.0
# Average Marks: 68.8

# %% [markdown]
# Smart Shopping Cart System
# Create a user-defined function called shopping_cart() that:
# 1.Allows the user to enter 5 product prices.
# 2.Stores the prices in a list.
# 3.Uses a loop to calculate the total bill.
# 4.Applies discounts using conditional statements:
# Total ≥ 5000 → 15% discount
# Total ≥ 3000 → 10% discount
# Total ≥ 1000 → 5% discount
# Otherwise → No discount
# 5.Displays:
# Product list
# Total amount
# Discount amount
# Final payable amoun

# %%
def shopping_cart():
    prices = []

    for i in range(5):
        price = float(input(f"Enter price of product {i+1}: "))
        prices.append(price)

    total = 0
    for price in prices:
        total += price

    if total >= 5000:
        discount = total * 0.15
    elif total >= 3000:
        discount = total * 0.10
    elif total >= 1000:
        discount = total * 0.05
    else:
        discount = 0

    final_amount = total - discount

    print("SHOPPING BILL")
    print("Product Prices:", prices)
    print("Total Amount:", total)
    print("Discount Amount:", discount)
    print("Final Payable Amount:", final_amount)

# Call function
shopping_cart()
# Out:
# Enter price of product 1: 100000
# Enter price of product 2: 3000
# Enter price of product 3: 3000
# Enter price of product 4: 4500
# Enter price of product 5: 10
# SHOPPING BILL
# Product Prices: [100000.0, 3000.0, 3000.0, 4500.0, 10.0]
# Total Amount: 110510.0
# Discount Amount: 16576.5
# Final Payable Amount: 93933.5
