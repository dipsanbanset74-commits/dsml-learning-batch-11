# %%
number=122
print(type(number))
# Out:
# <class 'int'>

# %%
num=3.4
type(num)
# Out:
# float

# %%
com=3+3j
type(com)
# Out:
# complex

# %% [markdown]
# type conversion (int to float)(float to int)

# %%
a=3.14
b=int(a)
b
# Out:
# 3

# %%
a=3
b=float(a)
b
# Out:
# 3.0

# %% [markdown]
# arthimetic operator

# %%
a=10
b=5
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a**2)
print(a%3)
print(a//7)
# Out:
# 15
# 5
# 50
# 2.0
# 100
# 1
# 1

# %% [markdown]
# comparision operator

# %%
a = 10
b = 5

print(a == b)
print(a != b)
print(a > b)
print(a < b)
print(a >= b)
print(a <= b)
# Out:
# False
# True
# True
# False
# True
# False

# %% [markdown]
# math function

# %%
import math
print(math.ceil(44.6))
# Out:
# 45

# %%
import math

math.factorial(9)
# Out:
# 362880

# %%
import math
math.floor(44.9)
# Out:
# 44

# %%
import math
math.gcd(3,6,9,12)
# Out:
# 3

# %%
import math
round(22.452,2)
# Out:
# 22.45

# %%
import math

user = 640
capacity = 128

result = min(user, capacity)

print(result)
# Out:
# 128

# %% [markdown]
# STRING

# %%
ab='hello'
bc="hello"
print(ab==bc)
# Out:
# True

# %%
text1="It's a sunny day"#clean
text2='hello "Dipsan"'#clean
print(text1)
print(text2)
# Out:
# It's a sunny day
# hello "Dipsan"

# %%
print(text1+text2)
# Out:
# It's a sunny dayhello "Dipsan"

# %% [markdown]
# repetition

# %%
print(text1*3)
# Out:
# It's a sunny dayIt's a sunny dayIt's a sunny day

# %% [markdown]
# indexing

# %%
data="Python"
print(data[-3])
print(data[5])
# Out:
# h
# n

# %% [markdown]
# slicing

# %%
#data[start:end:step]
data[1:4:2]
# Out:
# 'yh'

# %%
data[:-1]
# Out:
# 'Pytho'

# %%
data[3:]
# Out:
# 'hon'

# %%
data1="Hello Python"
data1[1:-1]
# Out:
# 'ello Pytho'

# %% [markdown]
# length

# %%
len(data1)
# Out:
# 12

# %%
data3 ="I am a girl"
print(data3.replace("girl","boy"))
# Out:
# I am a boy

# %%
data4 ="I am a boy"
print(data4.upper())
print(data4.lower())
print(data4.title())
print(data4.strip())
print(data4.split())
# Out:
# I AM A BOY
# i am a boy
# I Am A Boy
# I am a boy
# ['I', 'am', 'a', 'boy']

# %%
data5="     helllooo      "
data5.strip()
# Out:
# 'helllooo'

# %%
data6 = "image.png"
data6.endswith("png")
# Out:
# True
